# %%
# %matplotlib inline

# %% [markdown]
# # 10-fold cross-validation results for Control vs Heme

# %%
run -i postProcess_cv.py -opMode control_vs_heme
# Out:
# post-processing data for control_vs_heme
# Average validation accuracy over 10 folds:0.9458
# Average validation MCC over 10 folds:0.8479

# %% [markdown]
# # 10-fold cross-validation results for Control vs Nucleotide

# %%
run -i postProcess_cv.py -opMode control_vs_nucleotide
# Out:
# post-processing data for control_vs_nucleotide
# Average validation accuracy over 10 folds:0.8905
# Average validation MCC over 10 folds:0.7783
